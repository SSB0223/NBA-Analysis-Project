# %% [markdown]
# We want to train a model to predict an individual player's team statistics from a set group of 5 players. In otherwords, relative to an individual player's other 4 teammates, how well would that individual perform in a given season?
#
# Our reference/baseline point will be the starting lineups for each team.
# For example:
# The current projected starting lineup for the Lakers is currently Lonnie Walker, Patrick Beverley, Lebron James, Anthony Davis, and Damian Jones. Let's say we wanted to focus on Patrick Beverley's statistics. We can use his statistics with the team that season as a reference point for the model to try and find other players that average close to or similar stats as Patrick Beverley. We would want the model to predict stats with respect to the numbers that other players average as well. We know that Anthony Davis and Lebron James are high usage players, so any other player that accompany them will see a decrease in statistics. We expect bigger decreases for players that average more statistics and smaller decreases for players that average less statistics. Since Patrick Beverley is a guard, we would want to find guards that are simila

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

df = pd.read_excel('nba_full.xlsx')

teams = list(df['team.abbreviation'].unique())

appended_data = []

#iterates through each team
for ind_team in teams:
    #name each team temp 
    temp = df.loc[df['team.abbreviation'] == ind_team]
    #calculate ind_team total minutes played
    temp['TmMP'] = temp['mpg'].sum()
    #calculate ind_team total fga
    temp['TmFGA'] = temp['fga'].sum()
    #calculate ind_team total fta
    temp['TmFTA'] = temp['fta'].sum()
    #calculate ind_team total turnover rate
    temp['TmTOV'] = temp['turnover'].sum()
    #calculate indiv player usage metric within ind_team... usage formula online
    temp['usage'] = 100 * ((temp['fga'] + 0.44 * temp['fta'] + temp['turnover']) * (temp['TmMP'] / 5)) / (temp['mpg'] * (temp['TmFGA'] + 0.44 * temp['TmFTA'] + temp['TmTOV']))
    print(ind_team)
    
    appended_data.append(temp)
    
    
appended_data = pd.concat(appended_data)

appended_data
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
appended_data = appended_data[appended_data["usage"] >= 0]

# %%
appended_data.to_excel('nba_tidyfinal.xlsx')

# %%
hawks = appended_data[appended_data["team.abbreviation"] == "ATL"]

# %%
hawks
# Out:
#        id first_name last_name  height_feet  height_inches  actual_height_ft  \
# 40     83      Clint    Capela            6             10          6.833333
# 45    101       John   Collins            6             10          6.833333
# 103   213      Aaron   Holiday            6              1          6.083333
# 105   215     Justin   Holiday            6              6          6.500000
# 126   252      Frank  Kaminsky            7              0          7.000000
# 163   334   Dejounte    Murray            6              5          6.416667
# 240   490       Trae     Young            6              2          6.166667
# 247  3093     Onyeka   Okongwu            6              8          6.670000
# 248  3094         AJ   Griffin            6              6          6.500000
# 371  3218      Jalen   Johnson            6              8          6.670000
#
#     position  weight_pounds  team.id team.abbreviation team.city  \
# ...

# %% [markdown]
# Notes:
# No notable anomalies for usage rate for the hawks.

# %%
hornets = appended_data[appended_data["team.abbreviation"] == "CHA"]

# %%
hornets
# Out:
#        id first_name   last_name  height_feet  height_inches  \
# 98    204     Gordon     Hayward            6              8
# 178   360      Kelly   Oubre Jr.            6              7
# 182   371      Mason     Plumlee            6             11
# 199   403      Terry      Rozier            6              1
# 211   421     Dennis   Smith Jr.            6              3
# 249  3095     Lamelo        Ball            6              7
# 250  3096        PJ   Washington            6              7
# 251  3097      James   Bouknight            6              4
# 252  3098     Jalen    McDaniels            6              9
# 253  3099       Nick    Richards            7              0
#
#      actual_height_ft position  weight_pounds  team.id team.abbreviation  \
# 98           6.666667        F            225        4               CHA
# 178          6.583333        F            205        4               CHA
# ...

# %% [markdown]
# Note: Terry Rozier has a higher usage rate than Lamelo Ball, but this makes sense because Terry Rozier takes more shot attempts.

# %%
heat = appended_data[appended_data["team.abbreviation"] == "MIA"]

# %%
heat
# Out:
#        id first_name  last_name  height_feet  height_inches  actual_height_ft  \
# 1       4        Bam    Adebayo            6             10          6.833333
# 38     79      Jimmy     Butler            6              8          6.666667
# 55    120    Dewayne     Dedmon            7              0          7.000000
# 97    203     Udonis     Haslem            6              8          6.666667
# 143   286       Kyle      Lowry            6              1          6.083333
# 195   397     Duncan   Robinson            6              8          6.666667
# 246  3092    Haywood  Highsmith            6              7          6.583333
# 254  3100      Tyler      Herro            6              5          6.420000
# 255  3101      Caleb     Martin            6              5          6.420000
# 256  3102      Gabe      Vicent            6              3          6.250000
# 257  3103        Max      Strus            6              5          6.420000
#
# ...

# %% [markdown]
# Note: Tyler Herro has a higher usage rate than Butler, but this makes sense since he takes more shot attempts.

# %%
magic = appended_data[appended_data["team.abbreviation"] == "ORL"]

# %%
magic
# Out:
#        id first_name   last_name  height_feet  height_inches  \
# 12     28         Mo       Bamba            7              0
# 41     85    Wendell  Carter Jr.            6             10
# 198   402   Terrence        Ross            6              7
# 258  3104        Bol         Bol            7              2
# 259  3105      Franz      Wagner            6             10
# 260  3106      Paolo    Banchero            6             10
# 261  3107       Cole     Anthony            6              3
# 372  3219         RJ     Hampton            6              6
# 373  3220      Chuma       Okeke            6              6
# 374  3221     Jalen        Suggs            6              5
#
#      actual_height_ft position  weight_pounds  team.id team.abbreviation  \
# 12           7.000000        C            221       22               ORL
# 41           6.833333        F            255       22               ORL
# ...

# %% [markdown]
# Note: Nothing peculiar with the Magic with regards to usage rate.

# %%
wizards = appended_data[appended_data["team.abbreviation"] == "WAS"]

# %%
wizards
# Out:
#        id first_name  last_name  height_feet  height_inches  actual_height_ft  \
# 14     31       Will     Barton            6              6          6.500000
# 17     37    Bradley       Beal            6              5          6.416667
# 77    173        Taj     Gibson            6              9          6.750000
# 132   265       Kyle      Kuzma            6              9          6.750000
# 162   330      Monte     Morris            6              3          6.250000
# 187   378   Kristaps  Porzingis            7              3          7.250000
# 238   487      Delon     Wright            6              5          6.416667
# 262  3108       Deni     Avdija            6              9          6.750000
# 263  3109      Corey    Kispert            6              6          6.500000
# 264  3110        Rui  Hachimura            6              8          6.670000
# 265  3111     Daniel    Gafford            6              9          6.750000
#
# ...

# %% [markdown]
# Note: Taj Gibson's usage rate is abnormally high.

# %%
bulls = appended_data[appended_data["team.abbreviation"] == "CHI"]

# %%
bulls
# Out:
#        id first_name  last_name  height_feet  height_inches  actual_height_ft  \
# 27     60       Tony    Bradley            6             10          6.833333
# 43     89       Alex     Caruso            6              5          6.416667
# 57    125      DeMar    DeRozan            6              7          6.583333
# 63    136      Goran     Dragic            6              3          6.250000
# 64    137      Andre   Drummond            6             11          6.916667
# 121   247    Derrick  Jones Jr.            6              7          6.583333
# 133   268       Zach     LaVine            6              5          6.416667
# 225   460     Nikola    Vucevic            7              0          7.000000
# 266  3112        Ayo    Dosunmu            6              4          6.330000
# 267  3113   Patrick    Williams            6              7          6.580000
# 268  3114    Javonte      Green            6              5          6.420000
# ...

# %% [markdown]
# Note: Andre Drummond's usage rate is abnormally high.

# %%
cavs = appended_data[appended_data["team.abbreviation"] == "CLE"]

# %%
cavs
# Out:
#        id first_name last_name  height_feet  height_inches  actual_height_ft  \
# 3       9    Jarrett     Allen            6             11          6.916667
# 137   277      Caris    LeVert            6              7          6.583333
# 141   284      Robin     Lopez            7              0          7.000000
# 142   285      Kevin      Love            6             10          6.833333
# 158   322    Donovan  Mitchell            6              3          6.250000
# 168   343       Raul      Neto            6              1          6.083333
# 177   359       Cedi     Osman            6              8          6.666667
# 270  3116     Darius   Garland            6              1          6.080000
# 271  3117       Evan    Mobley            6             11          6.920000
# 272  3118       Dean      Wade            6              9          6.750000
# 273  3119      Isaac     Okoro            6              5          6.420000
#
# ...

# %% [markdown]
# Note: Nothing peculiar with the Cavs with regards to usage rate.

# %%
pistons = appended_data[appended_data["team.abbreviation"] == "DET"]

# %%
pistons
# Out:
#        id first_name   last_name  height_feet  height_inches  \
# 24     54      Bojan  Bogdanovic            6              8
# 58    128    Hamidou      Diallo            6              5
# 125   251       Cory      Joseph            6              3
# 129   259      Kevin        Knox            6              9
# 152   307     Rodney    McGruder            6              4
# 170   345    Nerlens        Noel            6             11
# 274  3120       Cade  Cunningham            6              6
# 275  3121      Jaden        Ivey            6              4
# 276  3122     Isaiah     Stewart            6              9
# 277  3123    Killian       Hayes            6              5
# 278  3124     Saddiq         Bey            6              8
# 279  3125     Isaiah      Livers            6              7
# 280  3126      Jalen       Duren            6             10
#
#      actual_height_ft position  weight_pounds  team.id team.abbreviation  \
# ...

# %% [markdown]
# Note: Nothing peculiar with the pistons with regard to usage rate.

# %%
pacers = appended_data[appended_data["team.abbreviation"] == "IND"]

# %%
pacers
# Out:
#        id first_name   last_name  height_feet  height_inches  \
# 101   210      Buddy       Hield            6              4
# 119   242      James     Johnson            6              8
# 149   304       T.J.   McConnell            6              2
# 220   452      Myles      Turner            6             11
# 281  3127     Tyrese  Haliburton            6              5
# 282  3128  Bennedict    Mathurin            6              6
# 283  3129      Chris      Duarte            6              5
# 284  3130      Jalen       Smith            6              9
# 285  3131      Oshae    Brissett            6              7
# 286  3132     Isaiah     Jackson            6              9
# 287  3133      Aaron     Nesmith            6              5
# 288  3134       Goga     Bitadze            6             11
#
#      actual_height_ft position  weight_pounds  team.id team.abbreviation  \
# 101          6.333333        G            214       12               IND
# ...

# %% [markdown]
# Note: Nothing peculiar with the pacers with regard to usage rate.

# %%
bucks = appended_data[appended_data["team.abbreviation"] == "MIL"]

# %%
bucks
# Out:
#        id first_name      last_name  height_feet  height_inches  \
# 2       8    Grayson          Allen            6              5
# 5      15    Giannis  Antetokounmpo            6             11
# 42     87      Jevon         Carter            6              2
# 102   211     George           Hill            6              3
# 104   214       Jrue        Holiday            6              4
# 109   223      Serge          Ibaka            6             10
# 140   283      Brook          Lopez            7              0
# 147   301     Wesley       Matthews            6              4
# 186   377      Bobby         Portis            6             11
# 242  2148   Thanasis  Antetokounmpo            6              6
# 289  3135     Jordan          Nwora            6              8
#
#      actual_height_ft position  weight_pounds  team.id team.abbreviation  \
# 2            6.416667        G            198       17               MIL
# ...

# %% [markdown]
# Note: Nothing peculiar with the bucks with regards to usage rate.

# %%
celtics = appended_data[appended_data["team.abbreviation"] == "BOS"]

# %%
celtics
# Out:
#        id first_name last_name  height_feet  height_inches  actual_height_ft  \
# 29     65    Malcolm   Brogdon            6              5          6.416667
# 33     70     Jaylen     Brown            6              7          6.583333
# 88    189      Blake   Griffin            6             10          6.833333
# 107   219         Al   Horford            6             10          6.833333
# 116   235     Justin   Jackson            6              8          6.666667
# 131   261       Luke    Kornet            7              1          7.083333
# 210   420     Marcus     Smart            6              4          6.333333
# 214   434     Jayson     Tatum            6              8          6.666667
# 224   459       Noah    Vonleh            6              9          6.750000
# 232   473    Derrick     White            6              4          6.333333
# 290  3136      Grant  Williams            6              6          6.500000
# ...

# %% [markdown]
# Note: Nothing peculiar with the Celtics with regard to usage rate.

# %%
nets = appended_data[appended_data["team.abbreviation"] == "BKN"]

# %%
nets
# Out:
#        id first_name last_name  height_feet  height_inches  actual_height_ft  \
# 52    114       Seth     Curry            6              2          6.166667
# 65    140      Kevin    Durant            6              9          6.750000
# 93    197        Joe    Harris            6              6          6.500000
# 113   228      Kyrie    Irving            6              3          6.250000
# 156   319      Patty     Mills            6              0          6.000000
# 161   329   Markieff    Morris            6              9          6.750000
# 173   351      Royce   O'Neale            6              6          6.500000
# 208   417        Ben   Simmons            6             10          6.833333
# 213   432     Edmond    Sumner            6              6          6.500000
# 230   470       Yuta  Watanabe            6              9          6.750000
# 292  3138        Nic   Claxton            6             11          6.920000
# ...

# %% [markdown]
# Note: Nothing peculiar with the Nets with regard to usage rate.

# %%
knicks = appended_data[appended_data["team.abbreviation"] == "NYK"]

# %%
knicks
# Out:
#        id first_name    last_name  height_feet  height_inches  \
# 8      19       Ryan  Arcidiacono            6              3
# 34     73      Jalen      Brunson            6              3
# 70    160       Evan     Fournier            6              7
# 95    201     Isaiah  Hartenstein            7              0
# 166   338        Svi   Mykhailiuk            6              8
# 191   387     Julius       Randle            6              9
# 196   399   Mitchell     Robinson            7              1
# 197   401    Derrick         Rose            6              3
# 294  3140        Cam      Reddish            6              8
# 295  3141         RJ      Barrett            6              6
# 296  3142   Immanuel     Quickley            6              3
# 297  3143   Quentin        Grimes            6              4
# 298  3144       Obi        Toppin            6              9
#
#      actual_height_ft position  weight_pounds  team.id team.abbreviation  \
# ...

# %% [markdown]
# Note: Svi has an abnormally high usage rate.

# %%
sixers = appended_data[appended_data["team.abbreviation"] == "PHI"]

# %%
sixers
# Out:
#        id  first_name  last_name  height_feet  height_inches  \
# 66    145        Joel     Embiid            7              0
# 90    192       James     Harden            6              5
# 91    194    Montrezl    Harrell            6              8
# 94    200      Tobias     Harris            6              9
# 130   260      Furkan    Korkmaz            6              7
# 153   313  De'Anthony     Melton            6              4
# 157   320       Shake     Milton            6              6
# 169   344     Georges      Niang            6              8
# 219   450          PJ     Tucker            6              6
# 243  2175      Danuel  House Jr.            6              7
# 299  3145      Tyrese      Maxey            6              2
# 300  3146        Paul       Reed            6              9
# 301  3147     Matisse   Thybulle            6              5
#
#      actual_height_ft position  weight_pounds  team.id team.abbreviation  \
# ...

# %% [markdown]
# Note: Shake Milton has an abnormally high usage rate.

# %%
raptors = appended_data[appended_data["team.abbreviation"] == "TOR"]

# %%
raptors
# Out:
#        id first_name    last_name  height_feet  height_inches  \
# 7      18         OG      Anunoby            6              8
# 21     46       Khem        Birch            6              9
# 26     58      Chris      Boucher            6             10
# 99    206    Juancho  Hernangomez            6              9
# 185   376       Otto   Porter Jr.            6              8
# 207   416     Pascal       Siakam            6              9
# 223   458       Fred     VanVleet            6              0
# 239   489   Thaddeus        Young            6              8
# 245  3089       Gary    Trent Jr.            6              6
# 302  3148    Scottie       Barnes            6              7
# 303  3149    Malachi        Flynn            6              1
# 304  3150     Dalano       Banton            6              7
# 305  3151   Precious      Achiuwa            6              8
#
#      actual_height_ft position  weight_pounds  team.id team.abbreviation  \
# ...

# %% [markdown]
# Note: Fred Vanvleet will have a lower usage rate than other players because of the lack of time spent on the court, which makes sense.

# %%
nuggets = appended_data[appended_data["team.abbreviation"] == "DEN"]

# %%
nuggets
# Out:
#        id  first_name      last_name  height_feet  height_inches  \
# 32     69       Bruce          Brown            6              5
# 39     81  Kentavious  Caldwell-Pope            6              5
# 80    177       Aaron         Gordon            6              9
# 87    188        Jeff          Green            6              9
# 120   246      Nikola          Jokic            7              0
# 124   250     DeAndre         Jordan            6             11
# 164   335       Jamal         Murray            6              4
# 184   375     Michael     Porter Jr.            6             10
# 192   390       Davon           Reed            6              5
# 212   422         Ish          Smith            6              0
# 306  3152       Bones         Hyland            6              2
#
#      actual_height_ft position  weight_pounds  team.id team.abbreviation  \
# 32           6.416667        G            202        8               DEN
# ...

# %% [markdown]
# Note: Ish Smith and Bones Hyland have high usage rates. The numbers might be skewed due to the lack of time that Michael Porter Jr and Jamal Murray shared together.

# %%
timberwolves = appended_data[appended_data["team.abbreviation"] == "MIN"]

# %%
timberwolves
# Out:
#        id    first_name   last_name  height_feet  height_inches  \
# 4      12          Kyle    Anderson            6              9
# 69    159          Bryn      Forbes            6              3
# 79    176          Rudy      Gobert            7              1
# 190   383       Taurean      Prince            6              8
# 194   393        Austin      Rivers            6              4
# 201   405      D'Angelo     Russell            6              5
# 218   447  Karl-Anthony       Towns            7              0
# 307  3153       Anthony     Edwards            6              4
# 308  3154         Jaden   McDaniels            6              9
# 309  3155        Jordan  McLaughlin            5             11
# 310  3156        Jaylen      Nowell            6              4
# 311  3157           Naz        Reid            6              9
#
#      actual_height_ft position  weight_pounds  team.id team.abbreviation  \
# ...

# %% [markdown]
# Note: Jaylen Nowell and Naz Reid have abnormally high usage rates.

# %%
thunder = appended_data[appended_data["team.abbreviation"] == "OKC"]

# %%
thunder
# Out:
#        id first_name           last_name  height_feet  height_inches  \
# 78    175       Shai  Gilgeous-Alexander            6              6
# 165   337       Mike             Muscala            6             11
# 235   480    Kenrich            Williams            6              7
# 312  3158       Josh              Giddey            6              8
# 313  3159      Jalen            Williams            6              6
# 314  3160    Lugentz                Dort            6              4
# 315  3161    Aleksej          Pokusevski            7              0
# 316  3162        Tre                Mann            6              3
# 317  3163      Aaron             Wiggins            6              5
# 318  3164     Darius              Bazley            6              9
# 319  3165   Jeremiah       Robinson-Earl            6              8
#
#      actual_height_ft position  weight_pounds  team.id team.abbreviation  \
# ...

# %% [markdown]
# Note: Nothing unusual for the Thunder with regards to usage rate.

# %%
blazers = appended_data[appended_data["team.abbreviation"] == "POR"]

# %%
blazers
# Out:
#        id first_name last_name  height_feet  height_inches  actual_height_ft  \
# 67    147       Drew   Eubanks            6             10          6.833333
# 83    182     Jerami     Grant            6              9          6.750000
# 96    202       Josh      Hart            6              5          6.416667
# 138   278     Damian   Lillard            6              3          6.250000
# 172   349      Jusuf    Nurkic            7              0          7.000000
# 209   419   Anfernee    Simons            6              4          6.333333
# 236   485    Justise   Winslow            6              7          6.583333
# 320  3166     Nassir    Little            6              5          6.420000
# 321  3167    Shaedon    Sharpe            6              6          6.500000
# 322  3168    Trendon   Watford            6              8          6.670000
#
#     position  weight_pounds  team.id team.abbreviation team.city  \
# ...

# %% [markdown]
# Note: Nothing unusual for the Trailblazers with regard to usage rate.

# %%
jazz = appended_data[appended_data["team.abbreviation"] == "UTA"]

# %%
jazz
# Out:
#        id first_name      last_name  height_feet  height_inches  \
# 18     38      Malik        Beasley            6              5
# 44    100     Jordan       Clarkson            6              5
# 47    104       Mike         Conley            6              1
# 75    171       Rudy            Gay            6              8
# 146   297      Lauri      Markkanen            7              0
# 176   358      Kelly         Olynyk            7              0
# 205   413     Collin         Sexton            6              2
# 222   457     Jarred     Vanderbilt            6              9
# 323  3169      Talen  Horton-Tucker            6              4
# 324  3170    Walker         Kessler            7              1
#
#      actual_height_ft position  weight_pounds  team.id team.abbreviation  \
# 18           6.416667        G            195       29               UTA
# 44           6.416667        G            194       29               UTA
# ...

# %% [markdown]
# Note: Nothing unusual for the Jazz with regard to usage rate.

# %%
warriors = appended_data[appended_data["team.abbreviation"] == "GSW"]

# %%
warriors
# Out:
#        id first_name   last_name  height_feet  height_inches  \
# 53    115    Stephen       Curry            6              3
# 61    131      Donte  DiVincenzo            6              4
# 85    185   Draymond       Green            6              7
# 86    187   JaMychal       Green            6              9
# 139   282      Kevon      Looney            6              9
# 217   443       Klay    Thompson            6              7
# 233   475     Andrew     Wiggins            6              8
# 325  3171     Jordan       Poole            6              4
# 326  3172     Moses        Moody            6              6
# 327  3173    Anthony        Lamb            6              6
# 328  3174   Jonathan     Kuminga            6              8
#
#      actual_height_ft position  weight_pounds  team.id team.abbreviation  \
# 53           6.250000        G            190       10               GSW
# 61           6.333333        G            203       10               GSW
# ...

# %% [markdown]
# Note: Nothing unusual for the Warriors with regard to usage rate.

# %%
clippers = appended_data[appended_data["team.abbreviation"] == "LAC"]

# %%
clippers
# Out:
#        id first_name   last_name  height_feet  height_inches  \
# 16     33    Nicolas       Batum            6              8
# 49    108     Robert   Covington            6              9
# 76    172       Paul      George            6              9
# 117   236     Reggie     Jackson            6              3
# 127   254       Luke     Kennard            6              5
# 136   274      Kawhi     Leonard            6              7
# 160   328     Marcus      Morris            6              9
# 189   380     Norman      Powell            6              4
# 228   467       John        Wall            6              4
# 241   493      Ivica       Zubac            7              1
# 329  3175     Moses        Brown            7              2
# 330  3176  Terrance         Mann            6              5
# 331  3177    Brandon  Boston Jr.            6              6
# 332  3178       Amir      Coffey            6              7
#
# ...

# %% [markdown]
# Note: Brandon Boston Jr. has an abnormally high usage rate.

# %%
lakers = appended_data[appended_data["team.abbreviation"] == "LAL"]

# %%
lakers
# Out:
#        id first_name         last_name  height_feet  height_inches  \
# 20     45    Patrick          Beverley            6              1
# 31     68       Troy         Brown Jr.            6              7
# 54    117    Anthony             Davis            6             10
# 73    166     Wenyen           Gabriel            6              9
# 118   237     LeBron             James            6              8
# 122   248     Damian             Jones            7              0
# 227   464     Lonnie         Walker IV            6              5
# 231   472    Russell         Westbrook            6              3
# 333  3179     Austin            Reaves            6              5
# 334  3180       Juan  Toscano-Anderson            6              6
# 335  3181      Matt               Ryan            6              7
#
#      actual_height_ft position  weight_pounds  team.id team.abbreviation  \
# 20           6.083333        G            185       14               LAL
# ...

# %% [markdown]
# Note: Nothing unusual about the Lakers with regard to usage rate.

# %%
suns = appended_data[appended_data["team.abbreviation"] == "PHX"]

# %%
suns
# Out:
#        id first_name last_name  height_feet  height_inches  actual_height_ft  \
# 9      22    Deandre     Ayton            7              1          7.083333
# 22     48    Bismack   Biyombo            6              9          6.750000
# 25     57      Devin    Booker            6              6          6.500000
# 28     61      Mikal   Bridges            6              7          6.583333
# 50    110     Torrey     Craig            6              7          6.583333
# 134   272     Damion       Lee            6              6          6.500000
# 174   356       Josh    Okogie            6              4          6.333333
# 179   367      Chris      Paul            6              0          6.000000
# 180   368    Cameron     Payne            6              1          6.080000
# 203   407      Dario     Saric            6             10          6.833333
# 206   414     Landry    Shamet            6              5          6.416667
# ...

# %% [markdown]
# Note: Cameron Payne has an abnormally high usage rate, but keep in mind he has been getting extensive minutes in the wake of Chris Paul's abscense.

# %%
kings = appended_data[appended_data["team.abbreviation"] == "SAC"]

# %%
kings
# Out:
#        id first_name    last_name  height_feet  height_inches  \
# 13     30   Harrison       Barnes            6              8
# 56    123    Matthew  Dellavedova            6              4
# 71    161   De'Aaron          Fox            6              3
# 106   217    Richaun       Holmes            6             10
# 108   221      Kevin      Huerter            6              7
# 135   273       Alex          Len            7              1
# 144   290       Trey        Lyles            6             10
# 154   314   Chimezie         Metu            6             10
# 159   324      Malik         Monk            6              3
# 202   406   Domantas      Sabonis            6             11
# 337  3184     Keegan       Murray            6              8
# 338  3185     Davion     Mitchell            6              0
# 339  3186   Terrence        Davis            6              4
#
#      actual_height_ft position  weight_pounds  team.id team.abbreviation  \
# ...

# %% [markdown]
# Note: Nothing unusual for the Kings with regard to usage rate.

# %%
mavericks = appended_data[appended_data["team.abbreviation"] == "DAL"]

# %%
mavericks
# Out:
#        id first_name     last_name  height_feet  height_inches  \
# 36     75     Reggie       Bullock            6              7
# 60    130    Spencer     Dinwiddie            6              6
# 62    132       Luka        Doncic            6              7
# 68    158     Dorian  Finney-Smith            6              8
# 89    191        Tim  Hardaway Jr.            6              6
# 128   257       Maxi        Kleber            6             11
# 151   306     JaVale         McGee            7              0
# 181   370       Theo        Pinson            6              6
# 188   379     Dwight        Powell            6             11
# 237   486  Christian          Wood            6             10
# 340  3187       Josh         Green            6              5
#
#      actual_height_ft position  weight_pounds  team.id team.abbreviation  \
# 36           6.583333      G-F            205        7               DAL
# ...

# %% [markdown]
# Note: Nothing unusual for the Mavs with regard to usage rate.

# %%
rockets = appended_data[appended_data["team.abbreviation"] == "HOU"]

# %%
rockets
# Out:
#        id first_name    last_name  height_feet  height_inches  \
# 81    178       Eric       Gordon            6              4
# 145   296      Boban   Marjanovic            7              3
# 341  3188      Kevin   Porter Jr.            6              4
# 342  3189      Jalen        Green            6              4
# 343  3190     Jabari    Smith Jr.            6             11
# 344  3191    Alperen       Sengun            6             11
# 345  3192   Garrison     Matthews            6              6
# 346  3193   Jae'Sean         Tate            6              5
# 347  3194     Kenyon   Martin Jr.            6              7
# 348  3195      Usman       Garuba            6              8
# 349  3196       Josh  Christopher            6              4
# 350  3197       Tari        Eason            6              8
#
#      actual_height_ft position  weight_pounds  team.id team.abbreviation  \
# 81           6.333333        G            215       11               HOU
# ...

# %% [markdown]
# Note: Boban has an abnormally high usage rate, but this is because he is very efficient in the minutes he is given.

# %%
grizzlies = appended_data[appended_data["team.abbreviation"] == "MEM"]

# %%
grizzlies
# Out:
#        id first_name last_name  height_feet  height_inches  actual_height_ft  \
# 0       3     Steven     Adams            7              0          7.000000
# 30     66     Dillon    Brooks            6              6          6.500000
# 123   249       Tyus     Jones            6              2          6.166667
# 351  3198         Ja    Morant            6              3          6.250000
# 352  3199    Desmond      Bane            6              5          6.420000
# 353  3200       John   Konchar            6              5          6.420000
# 354  3201      Santi    Aldama            6             11          6.920000
# 355  3202    Brandon    Clarke            6              8          6.670000
# 356  3203    Kennedy  Chandler            6              0          6.000000
# 357  3204      David     Roddy            6              5          6.420000
# 358  3205     Xavier   Tillman            6              8          6.670000
#
# ...

# %% [markdown]
# Note: Nothing unusual for the Grizzlies with regard to usage rate.

# %%
pelicans = appended_data[appended_data["team.abbreviation"] == "NOP"]

# %%
pelicans
# Out:
#        id first_name    last_name  height_feet  height_inches  \
# 82    180   Devonte'       Graham            6              2
# 100   207      Willy  Hernangomez            6             11
# 112   227    Brandon       Ingram            6              9
# 148   303         CJ     McCollum            6              3
# 167   340      Larry    Nance Jr.            6              9
# 215   436    Garrett       Temple            6              6
# 221   455      Jonas  Valanciunas            7              0
# 359  3206    Herbert        Jones            6              7
# 360  3207       Zion   Williamson            6              6
# 361  3208      Jose      Alvarado            6              0
# 362  3209      Trey    Murphy III            6              8
# 363  3210       Naji     Marshall            6              7
# 364  3211      Jaxon        Hayes            6             11
# 365  3212      Dyson      Daniels            6              6
#
# ...

# %% [markdown]
# Note: Willy Hernangomez has an abnormally high usage rate.

# %%
spurs = appended_data[appended_data["team.abbreviation"] == "SAS"]

# %%
spurs
# Out:
#        id first_name   last_name  height_feet  height_inches  \
# 15     32      Keita  Bates-Diop            6              9
# 46    102       Zach     Collins            7              0
# 59    129     Gorgui       Dieng            6             11
# 150   305       Doug   McDermott            6              8
# 183   373      Jakob      Poeltl            7              0
# 193   391       Josh  Richardson            6              6
# 366  3213       Tre        Jones            6              1
# 367  3214      Devin     Vassell            6              5
# 368  3215     Keldon     Johnson            6              5
# 369  3216     Jeremy      Sochan            6              8
# 370  3217     Romeo     Langford            6              5
#
#      actual_height_ft position  weight_pounds  team.id team.abbreviation  \
# 15           6.750000        F            229       27               SAS
# 46           7.000000      F-C            235       27               SAS
# ...

# %% [markdown]
# Note: Nothing unusual for the Spurs with regard to usage rate.

# %%
appended_data["usage"].mean()
# Out:
# 18.68585097954166

# %%
appended_data["usage"].min()
# Out:
# 0.0

# %%
appended_data["usage"].max()
# Out:
# 39.72109942633022

# %%
appended_data["usage"].nlargest(10)
# Out:
# 62     39.721099
# 5      37.504922
# 240    35.798669
# 351    35.244667
# 66     34.659545
# 138    34.362346
# 65     33.078748
# 71     32.743981
# 78     32.530404
# 53     32.186698
# Name: usage, dtype: float64

# %%
appended_data.loc[62]
# Out:
# id                                132
# first_name                       Luka
# last_name                      Doncic
# height_feet                         6
# height_inches                       7
# actual_height_ft             6.583333
# position                          F-G
# weight_pounds                     218
# team.id                             7
# team.abbreviation                 DAL
# team.city                      Dallas
# team.conference                  West
# team.division               Southwest
# team.full_name       Dallas Mavericks
# team.name                   Mavericks
# mpg                              36.5
# fgm                             12.38
# fga                              23.5
# fg_pct                          0.527
# fg3m                             2.13
# fg3a                             8.13
# fg3_pct                         0.262
# ftm                              9.13
# fta                             11.63
# ft_pct                          0.785
# ...

# %%
appended_data.loc[5]
# Out:
# id                                15
# first_name                   Giannis
# last_name              Antetokounmpo
# height_feet                        6
# height_inches                     11
# actual_height_ft            6.916667
# position                           F
# weight_pounds                    242
# team.id                           17
# team.abbreviation                MIL
# team.city                  Milwaukee
# team.conference                 East
# team.division                Central
# team.full_name       Milwaukee Bucks
# team.name                      Bucks
# mpg                        29.666667
# fgm                            10.44
# fga                            18.89
# fg_pct                         0.553
# fg3m                            0.89
# fg3a                            3.22
# fg3_pct                        0.276
# ftm                             7.22
# fta                            11.44
# ft_pct                         0.631
# ...

# %%
appended_data.loc[240]
# Out:
# id                             490
# first_name                    Trae
# last_name                    Young
# height_feet                      6
# height_inches                    2
# actual_height_ft          6.166667
# position                         G
# weight_pounds                  180
# team.id                          1
# team.abbreviation              ATL
# team.city                  Atlanta
# team.conference               East
# team.division            Southeast
# team.full_name       Atlanta Hawks
# team.name                    Hawks
# mpg                           35.1
# fgm                           8.67
# fga                          22.78
# fg_pct                        0.38
# fg3m                          2.44
# fg3a                           8.0
# fg3_pct                      0.306
# ftm                           8.44
# fta                           9.22
# ft_pct                       0.916
# oreb                          0.89
# dreb                          2.44
# ...

# %%
appended_data.loc[351]
# Out:
# id                                3198
# first_name                          Ja
# last_name                       Morant
# height_feet                          6
# height_inches                        3
# actual_height_ft                  6.25
# position                             G
# weight_pounds                      174
# team.id                             15
# team.abbreviation                  MEM
# team.city                      Memphis
# team.conference                   West
# team.division                Southwest
# team.full_name       Memphis Grizzlies
# team.name                    Grizzlies
# mpg                               33.2
# fgm                               10.3
# fga                               21.5
# fg_pct                            0.48
# fg3m                               2.1
# fg3a                               5.2
# fg3_pct                          0.403
# ftm                                6.6
# fta                                8.5
# ...

# %%
appended_data.loc[66]
# Out:
# id                                  145
# first_name                         Joel
# last_name                        Embiid
# height_feet                           7
# height_inches                         0
# actual_height_ft                    7.0
# position                            F-C
# weight_pounds                       250
# team.id                              23
# team.abbreviation                   PHI
# team.city                  Philadelphia
# team.conference                    East
# team.division                  Atlantic
# team.full_name       Philadelphia 76ers
# team.name                         76ers
# mpg                                20.7
# fgm                                 5.8
# fga                                10.9
# fg_pct                            0.532
# fg3m                                0.6
# fg3a                                2.0
# fg3_pct                             0.3
# ftm                                 4.1
# ...

# %%
appended_data.loc[138]
# Out:
# id                                      278
# first_name                           Damian
# last_name                           Lillard
# height_feet                               6
# height_inches                             3
# actual_height_ft                       6.25
# position                                  G
# weight_pounds                           195
# team.id                                  25
# team.abbreviation                       POR
# team.city                          Portland
# team.conference                        West
# team.division                     Northwest
# team.full_name       Portland Trail Blazers
# team.name                     Trail Blazers
# mpg                               19.433333
# fgm                                    5.33
# fga                                   10.78
# fg_pct                                0.495
# fg3m                                   2.22
# fg3a                                   5.67
# ...

# %%
appended_data.loc[65]
# Out:
# id                             140
# first_name                   Kevin
# last_name                   Durant
# height_feet                      6
# height_inches                    9
# actual_height_ft              6.75
# position                         F
# weight_pounds                  240
# team.id                          3
# team.abbreviation              BKN
# team.city                 Brooklyn
# team.conference               East
# team.division             Atlantic
# team.full_name       Brooklyn Nets
# team.name                     Nets
# mpg                           37.2
# fgm                           10.5
# fga                           20.3
# fg_pct                       0.517
# fg3m                           1.7
# fg3a                           5.1
# fg3_pct                      0.333
# ftm                            8.8
# fta                            9.3
# ft_pct                       0.946
# oreb                           0.4
# dreb                           5.8
# ...

# %%
appended_data.loc[71]
# Out:
# id                                161
# first_name                   De'Aaron
# last_name                         Fox
# height_feet                         6
# height_inches                       3
# actual_height_ft                 6.25
# position                            G
# weight_pounds                     175
# team.id                            26
# team.abbreviation                 SAC
# team.city                  Sacramento
# team.conference                  West
# team.division                 Pacific
# team.full_name       Sacramento Kings
# team.name                       Kings
# mpg                         27.866667
# fgm                              8.88
# fga                              16.0
# fg_pct                          0.555
# fg3m                             1.75
# fg3a                             4.75
# fg3_pct                         0.368
# ftm                               3.5
# fta                               4.0
# ft_pct                          0.875
# ...

# %%
appended_data.loc[78]
# Out:
# id                                     175
# first_name                            Shai
# last_name               Gilgeous-Alexander
# height_feet                              6
# height_inches                            6
# actual_height_ft                       6.5
# position                                 G
# weight_pounds                          181
# team.id                                 21
# team.abbreviation                      OKC
# team.city                    Oklahoma City
# team.conference                       West
# team.division                    Northwest
# team.full_name       Oklahoma City Thunder
# team.name                          Thunder
# mpg                              31.433333
# fgm                                  10.11
# fga                                  18.89
# fg_pct                               0.535
# fg3m                                  0.78
# fg3a                                  2.56
# fg3_pct                              0.304
# ...

# %%
appended_data.loc[53]
# Out:
# id                                     115
# first_name                         Stephen
# last_name                            Curry
# height_feet                              6
# height_inches                            3
# actual_height_ft                      6.25
# position                                 G
# weight_pounds                          190
# team.id                                 10
# team.abbreviation                      GSW
# team.city                     Golden State
# team.conference                       West
# team.division                      Pacific
# team.full_name       Golden State Warriors
# team.name                         Warriors
# mpg                                   31.3
# fgm                                    9.1
# fga                                   18.7
# fg_pct                               0.487
# fg3m                                   4.6
# fg3a                                  11.1
# fg3_pct                              0.414
# ...

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

df = pd.read_excel('nba_analysis.xlsx')

def locate_1():
    print('Please enter your team of Five!: \n')
    
    t = True
    while t:
        a = input('Name of Point Guard: ')
        if a in list(df['Full_name']):
            t = False
            return a
        else:
            print('\n')
            print('Name not recognized, please try again.')


def locate_2():
    
    t = True
    while t:
        b = input('Name of Shooting Guard: ')
        if b in list(df['Full_name']):
            t = False
            return b
        else:
            print('\n')
            print('Name not recognized, please try again.')



def locate_3():
    
    t = True
    while t:
        a = input('Name of Small Forward: ')
        if a in list(df['Full_name']):
            t = False
            return a
        else:
            print('\n')
            print('Name not recognized, please try again.')
            
def locate_4():
    
    t = True
    while t:
        a = input('Name of Power Forward: ')
        if a in list(df['Full_name']):
            t = False
            return a
        else:
            print('\n')
            print('Name not recognized, please try again.')

def locate_5():
   
    t = True
    while t:
        a = input('Name of Center: ')
        if a in list(df['Full_name']):
            t = False
            return a
        else:
            print('\n')
            print('Name not recognized, please try again.')

def team_builder():
    a = locate_1()
    b = locate_2()
    c = locate_3()
    d = locate_4()
    e = locate_5()
    return [a,b,c,d,e]

def locater(a):
    appended_data = []
    for i in a:
        new_loc = df.loc[df['Full_name'] == i]
        #print(i)
        appended_data.append(new_loc)
    appended_data = pd.concat(appended_data)
    return appended_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#builds team
nam = team_builder()

#creates df
t = locater(nam)
# Out:
# Please enter your team of Five!:

# %%
t
